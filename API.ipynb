# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete"

querystring = {"q":"tesla","region":"US"}

headers = {
	"X-RapidAPI-Key": "c86d19dba2msh0b9382a7f87c6a3p1f2116jsn57da44b7b1b0",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'explains': [], 'count': 15, 'quotes': [{'exchange': 'NMS', 'shortname': 'Tesla, Inc.', 'quoteType': 'EQUITY', 'symbol': 'TSLA', 'index': 'quotes', 'score': 806426.0, 'typeDisp': 'Equity', 'longname': 'Tesla, Inc.', 'exchDisp': 'NASDAQ', 'sector': 'Consumer Cyclical', 'sectorDisp': 'Consumer Cyclical', 'industry': 'Auto Manufacturers', 'industryDisp': 'Auto Manufacturers', 'dispSecIndFlag': True, 'isYahooFinance': True}, {'exchange': 'NEO', 'shortname': 'TESLA, INC. CDR (CAD HEDGED)', 'quoteType': 'EQUITY', 'symbol': 'TSLA.NE', 'index': 'quotes', 'score': 20800.0, 'typeDisp': 'Equity', 'longname': 'Tesla, Inc.', 'exchDisp': 'NEO', 'sector': 'Consumer Cyclical', 'sectorDisp': 'Consumer Cyclical', 'industry': 'Auto Manufacturers', 'industryDisp': 'Auto Manufacturers', 'isYahooFinance': True}, {'exchange': 'NEO', 'shortname': 'TESLA (TSLA) YIELD SHARES PURPO', 'quoteType': 'ETF', 'symbol': 'YTSL.NE', 'index': 'quotes', 'score': 20533.0, 'typeDisp': 'ETF', 'longname': 'Tesla (TSLA) Yiel
# ...

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v3/get-chart"

querystring = {"interval":"1d","symbol":"TSLA","range":"5y","region":"US","includePrePost":"false","useYfid":"true","includeAdjustedClose":"true","events":"capitalGain,div,split"}

headers = {
	"X-RapidAPI-Key": "c86d19dba2msh0b9382a7f87c6a3p1f2116jsn57da44b7b1b0",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'chart': {'result': [{'meta': {'currency': 'USD', 'symbol': 'TSLA', 'exchangeName': 'NMS', 'instrumentType': 'EQUITY', 'firstTradeDate': 1277818200, 'regularMarketTime': 1691697601, 'gmtoffset': -14400, 'timezone': 'EDT', 'exchangeTimezoneName': 'America/New_York', 'regularMarketPrice': 245.34, 'chartPreviousClose': 23.699, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'timezone': 'EDT', 'end': 1691760600, 'start': 1691740800, 'gmtoffset': -14400}, 'regular': {'timezone': 'EDT', 'end': 1691784000, 'start': 1691760600, 'gmtoffset': -14400}, 'post': {'timezone': 'EDT', 'end': 1691798400, 'start': 1691784000, 'gmtoffset': -14400}}, 'dataGranularity': '1d', 'range': '5y', 'validRanges': ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']}, 'timestamp': [1534167000, 1534253400, 1534339800, 1534426200, 1534512600, 1534771800, 1534858200, 1534944600, 1535031000, 1535117400, 1535376600, 1535463000, 1535549400, 1535635800, 1535722200, 1536067800, 1536154200, 153624060
# ...

# %%
response.json()['chart'].keys()
# Out:
# dict_keys(['result', 'error'])

# %%
response.json()['chart']['result'][0]['indicators']['quote'][0]
# Out:
# {'open': [24.075332641601562,
#   23.89666748046875,
#   22.79400062561035,
#   22.660667419433594,
#   21.566667556762695,
#   19.446666717529297,
#   20.707332611083984,
#   21.391332626342773,
#   21.275999069213867,
#   21.3799991607666,
#   21.200000762939453,
#   21.227333068847656,
#   20.684667587280273,
#   20.150667190551758,
#   20.133333206176758,
#   19.79599952697754,
#   19.003332138061523,
#   18.98666763305664,
#   17.34000015258789,
#   18.21733283996582,
#   18.631332397460938,
#   18.762666702270508,
#   19.201332092285156,
#   19.250667572021484,
#   19.336000442504883,
#   19.779333114624023,
#   18.700666427612305,
#   20.237333297729492,
#   19.84666633605957,
#   19.898666381835938,
#   20.0,
#   20.12733268737793,
#   20.860000610351562,
#   18.017332077026367,
#   20.384666442871094,
#   20.93000030517578,
#   20.222000122070312,
#   19.59666633605957,
#   18.309999465942383,
#   17.634666442871094,
#   17.016666412353516,
#   17.640666961669922,
# ...

# %%
close = response.json()['chart']['result'][0]['indicators']['quote'][0]['close']

# %%
close
# Out:
# [23.76066780090332,
#  23.176000595092773,
#  22.57933235168457,
#  22.363332748413086,
#  20.366666793823242,
#  20.562667846679688,
#  21.459999084472656,
#  21.44266700744629,
#  21.34000015258789,
#  21.521333694458008,
#  21.284666061401367,
#  20.790666580200195,
#  20.333999633789062,
#  20.209999084472656,
#  20.110666275024414,
#  19.26333236694336,
#  18.715999603271484,
#  18.729999542236328,
#  17.549333572387695,
#  19.03333282470703,
#  18.62933349609375,
#  19.369333267211914,
#  19.297332763671875,
#  19.68000030517578,
#  19.6560001373291,
#  18.997333526611328,
#  19.934667587280273,
#  19.8886661529541,
#  19.940000534057617,
#  19.978666305541992,
#  20.06599998474121,
#  20.6386661529541,
#  20.501333236694336,
#  17.65133285522461,
#  20.713333129882812,
#  20.06800079345703,
#  19.65333366394043,
#  18.788667678833008,
#  17.463333129882812,
#  16.70400047302246,
#  17.520000457763672,
#  17.125333786010742,
#  16.815332412719727,
#  17.25200080871582,
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(close)
